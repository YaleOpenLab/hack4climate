# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("/Users/yuesongyang/Desktop/Hack4Climate/socioeconomic_indicators_GDP.xlsx")

# %%
df2 = pd.read_excel("/Users/yuesongyang/Desktop/Hack4Climate/socioeconomic_indicators_pop_growth.xlsx")

# %%
df.head()
# Out:
#        country ISO code   GDP in 2011  GDP  in 2012  GDP  in 2013  \
# 0  Afghanistan      AFG  1.793024e+10  2.053654e+10  2.004633e+10
# 1      Albania      ALB  1.289087e+10  1.231978e+10  1.278103e+10
# 2      Algeria      DZA  2.000000e+11  2.090000e+11  2.100000e+11
# 3      Andorra      AND  3.427023e+09  3.146152e+09  3.248925e+09
# 4       Angola      AGO  1.040000e+11  1.150000e+11  1.250000e+11
#
#     GDP in 2014  GDP  in 2015   GDP in 2016  Country GDP rank in 2011  \
# 0  2.005019e+10  1.970299e+10  1.946902e+10                     110.0
# 1  1.321986e+10  1.139037e+10  1.192689e+10                     121.0
# 2  2.140000e+11  1.650000e+11  1.560000e+11                      47.0
# 3           NaN           NaN           NaN                     156.0
# 4  1.270000e+11  1.030000e+11  8.963316e+10                      59.0
#
#    Country GDP rank in 2012                 ...                   \
# 0                     105.0                 ...
# ...

# %%
df2.head()
# Out:
#        Country ISO three letter country code  \
# 0  Afghanistan                           AFG
# 1      Albania                           ALB
# 2      Algeria                           DZA
# 3      Andorra                           AND
# 4       Angola                           AGO
#
#    Population of the country in 2016  Population of the country in 2011  \
# 0                         34656032.0                         29708599.0
# 1                          2876101.0                          2905195.0
# 2                         40606052.0                         36819558.0
# 3                            77281.0                            83751.0
# 4                         28813463.0                         24218565.0
#
#    Population rank in 2016  Population rank in 2011  \
# 0                     40.0                       41
# 1                    136.0                      135
# 2                     34.0                       34
# ...

# %%
df2=df2.rename(columns = {'Country':'country'})

# %%
df2.columns
# Out:
# Index(['country', 'ISO three letter country code',
#        'Population of the country in 2016',
#        'Population of the country in 2011', 'Population rank in 2016',
#        'Population rank in 2011', 'Population growth rate in 2016',
#        'Population growth rate in 2011',
#        'Rank of population growth rate in 2016',
#        'Rank of population growth rate in 2011'],
#       dtype='object')

# %%
result = pd.merge(df, df2, on='country')

# %%
result.head()
# Out:
#        country ISO code   GDP in 2011  GDP  in 2012  GDP  in 2013  \
# 0  Afghanistan      AFG  1.793024e+10  2.053654e+10  2.004633e+10
# 1      Albania      ALB  1.289087e+10  1.231978e+10  1.278103e+10
# 2      Algeria      DZA  2.000000e+11  2.090000e+11  2.100000e+11
# 3      Andorra      AND  3.427023e+09  3.146152e+09  3.248925e+09
# 4       Angola      AGO  1.040000e+11  1.150000e+11  1.250000e+11
#
#     GDP in 2014  GDP  in 2015   GDP in 2016  Country GDP rank in 2011  \
# 0  2.005019e+10  1.970299e+10  1.946902e+10                     110.0
# 1  1.321986e+10  1.139037e+10  1.192689e+10                     121.0
# 2  2.140000e+11  1.650000e+11  1.560000e+11                      47.0
# 3           NaN           NaN           NaN                     156.0
# 4  1.270000e+11  1.030000e+11  8.963316e+10                      59.0
#
#    Country GDP rank in 2012                   ...                    \
# 0                     105.0                   ...
# ...

# %%
result.columns
# Out:
# Index(['country', 'ISO code', 'GDP in 2011', 'GDP  in 2012', 'GDP  in 2013',
#        'GDP in 2014', 'GDP  in 2015', 'GDP in 2016',
#        'Country GDP rank in 2011', 'Country GDP rank in 2012',
#        'Country GDP rank in 2013', 'Country GDP rank in 2014',
#        'Country GDP rank in 2015', 'Country GDP rank in 2016',
#        'GDP per capita in 2011', 'GDP per capita  in 2012',
#        'GDP per capita  in 2013', 'GDP per capita  in 2014',
#        'GDP per capita in 2015', 'GDP per capita  in 2016',
#        'Country GDP per capita rank in 2011',
#        'Country GDP per capita rank in 2012',
#        'Country GDP per capita rank in 2013',
#        'Country GDP per capita rank in 2014',
#        'Country GDP per capita rank in 2015',
#        'Country GDP per capita rank in 2016', 'ISO three letter country code',
#        'Population of the country in 2016',
#        'Population of the country in 2011', 'Population rank in 2016',
# ...

# %%
countries=["CHN","IND","JPN","BRA","CAN","USA","GBR","FRA","ITA","DEU"]
top10_GDP=result.loc[result['ISO code'].isin(countries)]
top10_GDP=top10_GDP.sort_values(by=['Country GDP rank in 2016'])
top10_GDP
# Out:
#             country ISO code   GDP in 2011  GDP  in 2012  GDP  in 2013  \
# 184   United States      USA  1.550000e+13  1.620000e+13  1.670000e+13
# 35            China      CHN  7.570000e+12  8.560000e+12  9.610000e+12
# 83            Japan      JPN  6.160000e+12  6.200000e+12  5.160000e+12
# 63          Germany      DEU  3.760000e+12  3.540000e+12  3.750000e+12
# 183  United Kingdom      GBR  2.610000e+12  2.650000e+12  2.720000e+12
# 59           France      FRA  2.860000e+12  2.680000e+12  2.810000e+12
# 75            India      IND  1.820000e+12  1.830000e+12  1.860000e+12
# 81            Italy      ITA  2.280000e+12  2.070000e+12  2.130000e+12
# 23           Brazil      BRA  2.620000e+12  2.470000e+12  2.470000e+12
# 31           Canada      CAN  1.790000e+12  1.820000e+12  1.840000e+12
#
#       GDP in 2014  GDP  in 2015   GDP in 2016  Country GDP rank in 2011  \
# 184  1.740000e+13  1.800000e+13  1.860000e+13                       1.0
# ...

# %%
top10_Pop=result.loc[result['Population rank in 2016'] <= 10]
top10_Pop=top10_Pop.sort_values(by=['Population rank in 2016'])
top10_Pop
# Out:
#                 country ISO code   GDP in 2011  GDP  in 2012  GDP  in 2013  \
# 35                China      CHN  7.570000e+12  8.560000e+12  9.610000e+12
# 75                India      IND  1.820000e+12  1.830000e+12  1.860000e+12
# 184       United States      USA  1.550000e+13  1.620000e+13  1.670000e+13
# 76            Indonesia      IDN  8.930000e+11  9.180000e+11  9.130000e+11
# 23               Brazil      BRA  2.620000e+12  2.470000e+12  2.470000e+12
# 130            Pakistan      PAK  2.140000e+11  2.240000e+11  2.310000e+11
# 127             Nigeria      NGA  4.120000e+11  4.610000e+11  5.150000e+11
# 13           Bangladesh      BGD  1.290000e+11  1.330000e+11  1.500000e+11
# 141  Russian Federation      RUS  2.030000e+12  2.170000e+12  2.230000e+12
# 111              Mexico      MEX  1.170000e+12  1.190000e+12  1.260000e+12
#
#       GDP in 2014  GDP  in 2015   GDP in 2016  Country GDP rank in 2011  \
# ...

# %%
df3=pd.read_excel("/Users/yuesongyang/Desktop/Hack4Climate/CW_WB_Climate_Vulnerability_Readiness_31102017.xlsx", 
                  sheet_name="Vulnerability_Readiness")

# %%
df3.head()
# Out:
#   country  Population living below the national income poverty line  \
# 0     AFG                                               35.8
# 1     AGO                                                NaN
# 2     ALB                                               14.3
# 3     AND                                                NaN
# 4     ARE                                                NaN
#
#    Climate Risk Score  Vulnerability score  Readiness score  \
# 0               36.17             0.633770         0.281464
# 1              106.67             0.566557         0.289926
# 2              125.50             0.386407         0.525043
# 3                 NaN                  NaN              NaN
# 4              154.67             0.364053         0.603236
#
#          Link to climate risk and adaptation profile Droughts Storms  \
# 0  http://sdwebx.worldbank.org/climateportal/coun...      YES    YES
# 1                                                NaN      NaN    NaN
# ...

# %%
df3=df3.iloc[:,:5]

# %%
df3.head()
# Out:
#   country  Population living below the national income poverty line  \
# 0     AFG                                               35.8
# 1     AGO                                                NaN
# 2     ALB                                               14.3
# 3     AND                                                NaN
# 4     ARE                                                NaN
#
#    Climate Risk Score  Vulnerability score  Readiness score
# 0               36.17             0.633770         0.281464
# 1              106.67             0.566557         0.289926
# 2              125.50             0.386407         0.525043
# 3                 NaN                  NaN              NaN
# 4              154.67             0.364053         0.603236

# %%
df3=df3.rename(columns = {"country" : "ISO code"})

# %%
top10_GDP = pd.merge(top10_GDP, df3, on='ISO code')

# %%
top10_GDP
# Out:
#           country ISO code   GDP in 2011  GDP  in 2012  GDP  in 2013  \
# 0   United States      USA  1.550000e+13  1.620000e+13  1.670000e+13
# 1           China      CHN  7.570000e+12  8.560000e+12  9.610000e+12
# 2           Japan      JPN  6.160000e+12  6.200000e+12  5.160000e+12
# 3         Germany      DEU  3.760000e+12  3.540000e+12  3.750000e+12
# 4  United Kingdom      GBR  2.610000e+12  2.650000e+12  2.720000e+12
# 5          France      FRA  2.860000e+12  2.680000e+12  2.810000e+12
# 6           India      IND  1.820000e+12  1.830000e+12  1.860000e+12
# 7           Italy      ITA  2.280000e+12  2.070000e+12  2.130000e+12
# 8          Brazil      BRA  2.620000e+12  2.470000e+12  2.470000e+12
# 9          Canada      CAN  1.790000e+12  1.820000e+12  1.840000e+12
#
#     GDP in 2014  GDP  in 2015   GDP in 2016  Country GDP rank in 2011  \
# 0  1.740000e+13  1.800000e+13  1.860000e+13                       1.0
# ...

# %%
top10_Pop = pd.merge(top10_Pop, df3, on='ISO code')

# %%
top10_Pop
# Out:
#               country ISO code   GDP in 2011  GDP  in 2012  GDP  in 2013  \
# 0               China      CHN  7.570000e+12  8.560000e+12  9.610000e+12
# 1               India      IND  1.820000e+12  1.830000e+12  1.860000e+12
# 2       United States      USA  1.550000e+13  1.620000e+13  1.670000e+13
# 3           Indonesia      IDN  8.930000e+11  9.180000e+11  9.130000e+11
# 4              Brazil      BRA  2.620000e+12  2.470000e+12  2.470000e+12
# 5            Pakistan      PAK  2.140000e+11  2.240000e+11  2.310000e+11
# 6             Nigeria      NGA  4.120000e+11  4.610000e+11  5.150000e+11
# 7          Bangladesh      BGD  1.290000e+11  1.330000e+11  1.500000e+11
# 8  Russian Federation      RUS  2.030000e+12  2.170000e+12  2.230000e+12
# 9              Mexico      MEX  1.170000e+12  1.190000e+12  1.260000e+12
#
#     GDP in 2014  GDP  in 2015   GDP in 2016  Country GDP rank in 2011  \
# 0  1.050000e+13  1.110000e+13  1.120000e+13                       2.0
# ...

# %%
top10_Pop.to_csv("top10ByPopulation_economic_Indicator.csv")

# %%
top10_GDP.to_csv("top10ByGDP_economic_Indicator.csv")

# %%
df4=pd.read_excel("/Users/yuesongyang/Desktop/Hack4Climate/CW_CAIT_GHG_Emissions_31102017.xlsx",sheet_name="GHG Emissions")

# %%
df4.head()
# Out:
#        Country  Year  \
# 0  Afghanistan  1990
# 1  Afghanistan  1991
# 2  Afghanistan  1992
# 3  Afghanistan  1993
# 4  Afghanistan  1994
#
#    Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)  \
# 0                                          15.212848
# 1                                          15.286439
# 2                                          14.010531
# 3                                          14.028118
# 4                                          13.985408
#
#    Total GHG Emissions Including Land-Use Change and Forestry (MtCO₂e‍)  \
# 0                                          15.212848
# 1                                          15.286439
# 2                                          14.010531
# 3                                          14.028118
# 4                                          13.985408
#
#    Total CO2 (excluding Land-Use Change and Forestry) (MtCO2)  \
# 0                                           2.915024
# ...

# %%
EU=['AUT', 'BEL', 'BGR', 'HRV', 'CYP', 'CZE', 'DNK', 'EST', 'FIN', 'FRA', 'DEU', 'GRC', 'HUN', 'IRL', 
          'ITA', 'LVA', 'LTU', 'LUX', 'MLT', 'NLD', 'POL', 'PRT', 'ROU', 'SVK', 'SVN', 'ESP', 'SWE', 'GBR']
Names=df.loc[df['ISO code'].isin(EU)]

# %%
Names=Names['country']

# %%
Names
# Out:
# 9              Austria
# 16             Belgium
# 25            Bulgaria
# 42             Croatia
# 44              Cyprus
# 45      Czech Republic
# 46             Denmark
# 55             Estonia
# 58             Finland
# 59              France
# 63             Germany
# 65              Greece
# 73             Hungary
# 79             Ireland
# 81               Italy
# 93              Latvia
# 99           Lithuania
# 100         Luxembourg
# 107              Malta
# 123        Netherlands
# 137             Poland
# 138           Portugal
# 140            Romania
# 152    Slovak Republic
# 153           Slovenia
# 158              Spain
# 166             Sweden
# 183     United Kingdom
# Name: country, dtype: object

# %%
Names=Names.tolist()

# %%
df4=df4.loc[df4['Country'].isin(Names)]

# %%
df4
# Out:
#              Country  Year  \
# 225          Austria  1990
# 226          Austria  1991
# 227          Austria  1992
# 228          Austria  1993
# 229          Austria  1994
# 230          Austria  1995
# 231          Austria  1996
# 232          Austria  1997
# 233          Austria  1998
# 234          Austria  1999
# 235          Austria  2000
# 236          Austria  2001
# 237          Austria  2002
# 238          Austria  2003
# 239          Austria  2004
# 240          Austria  2005
# 241          Austria  2006
# 242          Austria  2007
# 243          Austria  2008
# 244          Austria  2009
# 245          Austria  2010
# 246          Austria  2011
# 247          Austria  2012
# 248          Austria  2013
# 249          Austria  2014
# 400          Belgium  1990
# 401          Belgium  1991
# 402          Belgium  1992
# 403          Belgium  1993
# 404          Belgium  1994
# ...              ...   ...
# 4170          Sweden  2010
# 4171          Sweden  2011
# ...

# %%
df4.to_csv("EU_GHG_emission.csv")

# %%
df5=pd.read_excel("/Users/yuesongyang/Desktop/Hack4Climate/CW_CAIT_GHG_Emissions_31102017.xlsx",
                  sheet_name="GHG Emissions")

# %%
SEA=["Malaysia", "Cambodia", "Indonesia", "Philippines", "East Timor", "Laos", 
     "Singapore", "Vietnam", "Brunei", "Burma", "Thailand"]
df5=df5.loc[df5['Country'].isin(SEA)]

# %%
df5
# Out:
#        Country  Year  \
# 600     Brunei  1990
# 601     Brunei  1991
# 602     Brunei  1992
# 603     Brunei  1993
# 604     Brunei  1994
# 605     Brunei  1995
# 606     Brunei  1996
# 607     Brunei  1997
# 608     Brunei  1998
# 609     Brunei  1999
# 610     Brunei  2000
# 611     Brunei  2001
# 612     Brunei  2002
# 613     Brunei  2003
# 614     Brunei  2004
# 615     Brunei  2005
# 616     Brunei  2006
# 617     Brunei  2007
# 618     Brunei  2008
# 619     Brunei  2009
# 620     Brunei  2010
# 621     Brunei  2011
# 622     Brunei  2012
# 623     Brunei  2013
# 624     Brunei  2014
# 700   Cambodia  1990
# 701   Cambodia  1991
# 702   Cambodia  1992
# 703   Cambodia  1993
# 704   Cambodia  1994
# ...        ...   ...
# 4295  Thailand  2010
# 4296  Thailand  2011
# 4297  Thailand  2012
# 4298  Thailand  2013
# 4299  Thailand  2014
# 4700   Vietnam  1990
# 4701   Vietnam  1991
# 4702   Vietnam  1992
# 4703   Vietnam  1993
# 4704   Vietnam  1994
# 4705   Vietnam  1995
# ...

# %%
df5.to_csv("SEA_GHG_emission.csv")

# %%
df6=pd.read_excel("/Users/yuesongyang/Desktop/Hack4Climate/CW_CAIT_GHG_Emissions_31102017.xlsx",
                 sheet_name="CO2 Total Emissions")

# %%
df6.head(15)
# Out:
#               Country  Year  \
# 0         Afghanistan  1850
# 1             Albania  1850
# 2             Algeria  1850
# 3             Andorra  1850
# 4              Angola  1850
# 5   Antigua & Barbuda  1850
# 6           Argentina  1850
# 7             Armenia  1850
# 8           Australia  1850
# 9             Austria  1850
# 10         Azerbaijan  1850
# 11            Bahamas  1850
# 12            Bahrain  1850
# 13         Bangladesh  1850
# 14           Barbados  1850
#
#     Total CO2 Emissions Excluding Land-Use Change and Forestry (MtCO2)
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# ...

# %%
df6=df6.dropna()

# %%
df6.head()
# Out:
#        Country  Year  \
# 7      Armenia  1850
# 9      Austria  1850
# 10  Azerbaijan  1850
# 15     Belarus  1850
# 16     Belgium  1850
#
#     Total CO2 Emissions Excluding Land-Use Change and Forestry (MtCO2)
# 7                                            0.000426
# 9                                            2.326640
# 10                                           0.001583
# 15                                           0.003059
# 16                                           9.332208

# %%
df6=df6.loc[df6["Year"] > 2000]

# %%
EU_CO2=df6.loc[df6["Country"].isin(Names)]

# %%
SEA_CO2=df6.loc[df6["Country"].isin(SEA)]

# %%
EU_CO2.to_csv("EU_CO2_emission.csv")

# %%
SEA_CO2.to_csv("SEA_CO2_emission.csv")

# %%
top10_GDP
# Out:
#           country ISO code   GDP in 2011  GDP  in 2012  GDP  in 2013  \
# 0   United States      USA  1.550000e+13  1.620000e+13  1.670000e+13
# 1           China      CHN  7.570000e+12  8.560000e+12  9.610000e+12
# 2           Japan      JPN  6.160000e+12  6.200000e+12  5.160000e+12
# 3         Germany      DEU  3.760000e+12  3.540000e+12  3.750000e+12
# 4  United Kingdom      GBR  2.610000e+12  2.650000e+12  2.720000e+12
# 5          France      FRA  2.860000e+12  2.680000e+12  2.810000e+12
# 6           India      IND  1.820000e+12  1.830000e+12  1.860000e+12
# 7           Italy      ITA  2.280000e+12  2.070000e+12  2.130000e+12
# 8          Brazil      BRA  2.620000e+12  2.470000e+12  2.470000e+12
# 9          Canada      CAN  1.790000e+12  1.820000e+12  1.840000e+12
#
#     GDP in 2014  GDP  in 2015   GDP in 2016  Country GDP rank in 2011  \
# 0  1.740000e+13  1.800000e+13  1.860000e+13                       1.0
# ...

# %%
Top10_names=top10_GDP["country"].tolist()

# %%
Top10_names
# Out:
# ['United States',
#  'China',
#  'Japan',
#  'Germany',
#  'United Kingdom',
#  'France',
#  'India',
#  'Italy',
#  'Brazil',
#  'Canada']

# %%
df6.head()
# Out:
#            Country  Year  \
# 29143  Afghanistan  2001
# 29144      Albania  2001
# 29145      Algeria  2001
# 29146      Andorra  2001
# 29147       Angola  2001
#
#        Total CO2 Emissions Excluding Land-Use Change and Forestry (MtCO2)
# 29143                                           0.795088
# 29144                                           3.220000
# 29145                                          75.123829
# 29146                                           0.523952
# 29147                                          12.963733

# %%
df7=pd.read_excel("/Users/yuesongyang/Desktop/Hack4Climate/CW_CAIT_GHG_Emissions_31102017.xlsx",
                 sheet_name="CO2 Total Emissions")

# %%
Top10_CO2=df7.loc[df7["Country"].isin(Top10_names)]

# %%
Top10_CO2.Country.unique()
# Out:
# array(['Brazil', 'Canada', 'China', 'France', 'Germany', 'India', 'Italy',
#        'Japan', 'United Kingdom'], dtype=object)

# %%
Top10_CO2.to_csv("Top10_CO2.csv")

# %%
UK=Top10_CO2.loc[Top10_CO2["Country"]=="United Kingdom"]

# %%
UK
# Out:
#               Country  Year  \
# 182    United Kingdom  1850
# 375    United Kingdom  1851
# 568    United Kingdom  1852
# 761    United Kingdom  1853
# 954    United Kingdom  1854
# 1147   United Kingdom  1855
# 1340   United Kingdom  1856
# 1533   United Kingdom  1857
# 1726   United Kingdom  1858
# 1919   United Kingdom  1859
# 2112   United Kingdom  1860
# 2305   United Kingdom  1861
# 2498   United Kingdom  1862
# 2691   United Kingdom  1863
# 2884   United Kingdom  1864
# 3077   United Kingdom  1865
# 3270   United Kingdom  1866
# 3463   United Kingdom  1867
# 3656   United Kingdom  1868
# 3849   United Kingdom  1869
# 4042   United Kingdom  1870
# 4235   United Kingdom  1871
# 4428   United Kingdom  1872
# 4621   United Kingdom  1873
# 4814   United Kingdom  1874
# 5007   United Kingdom  1875
# 5200   United Kingdom  1876
# 5393   United Kingdom  1877
# 5586   United Kingdom  1878
# 5779   United Kingdom  1879
# ...               ...   ...
# 26237  United Kingdom  1985
# ...

# %%
UK.to_excel("UK.xlsx")

# %%
top10_GDP
# Out:
#           country ISO code   GDP in 2011  GDP  in 2012  GDP  in 2013  \
# 0   United States      USA  1.550000e+13  1.620000e+13  1.670000e+13
# 1           China      CHN  7.570000e+12  8.560000e+12  9.610000e+12
# 2           Japan      JPN  6.160000e+12  6.200000e+12  5.160000e+12
# 3         Germany      DEU  3.760000e+12  3.540000e+12  3.750000e+12
# 4  United Kingdom      GBR  2.610000e+12  2.650000e+12  2.720000e+12
# 5          France      FRA  2.860000e+12  2.680000e+12  2.810000e+12
# 6           India      IND  1.820000e+12  1.830000e+12  1.860000e+12
# 7           Italy      ITA  2.280000e+12  2.070000e+12  2.130000e+12
# 8          Brazil      BRA  2.620000e+12  2.470000e+12  2.470000e+12
# 9          Canada      CAN  1.790000e+12  1.820000e+12  1.840000e+12
#
#     GDP in 2014  GDP  in 2015   GDP in 2016  Country GDP rank in 2011  \
# 0  1.740000e+13  1.800000e+13  1.860000e+13                       1.0
# ...

# %%
scores=top10_GDP.iloc[:,-3:]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scores=scores[]
# Out:
#   File "<ipython-input-62-969129bd3448>", line 1
#     scores=scores[]
#                   ^
# SyntaxError: invalid syntax

# %%
df8=pd.read_excel("/Users/yuesongyang/Desktop/Hack4Climate/CW_WB_Climate_Vulnerability_Readiness_31102017.xlsx")

# %%
df8
# Out:
#     country  Population living below the national income poverty line  \
# 0       AFG                                               35.8
# 1       AGO                                                NaN
# 2       ALB                                               14.3
# 3       AND                                                NaN
# 4       ARE                                                NaN
# 5       ARG                                                NaN
# 6       ARM                                               30.0
# 7       ATG                                                NaN
# 8       AUS                                                NaN
# 9       AUT                                                NaN
# 10      AZE                                                6.0
# 11      BDI                                               64.6
# 12      BEL                                                NaN
# 13      BEN                                               36.2
# ...

# %%
Top10_names
# Out:
# ['United States',
#  'China',
#  'Japan',
#  'Germany',
#  'United Kingdom',
#  'France',
#  'India',
#  'Italy',
#  'Brazil',
#  'Canada']
